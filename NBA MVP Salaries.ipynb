# %%
import pandas as pd
from sqlalchemy import create_engine
from config import user, password

# %%
players_file= "Resources/players.csv"

# %%
salaries_file = "Resources/salaries.csv"

# %%
mvp_file = "Resources/mvp_finals.csv"

# %%
#Extract CSV into DataFrames
mvp_df=pd.read_csv(mvp_file)
mvp_df.head()
#Grab Columns
mvp_col=['Year','MVP_Name','MVP_Team', 'MVP_status']
new_mvp_df = mvp_df[mvp_col].copy()

# %%
#Rename Columns
new_mvp_df=new_mvp_df.rename(columns={'Year':'year','MVP_Name':'name','MVP_Team':'team','MVP_status':'finals_status'})
new_mvp_df
# Out:
#     year               name                   team      finals_status
# 0   1950                NaN                    NaN                NaN
# 1   1951                NaN                    NaN                NaN
# 2   1952                NaN                    NaN                NaN
# 3   1953                NaN                    NaN                NaN
# 4   1954                NaN                    NaN                NaN
# ..   ...                ...                    ...                ...
# 64  2014       Kevin Durant  Oklahoma City Thunder  Not reached Final
# 65  2015      Stephen Curry  Golden State Warriors           Champion
# 66  2016      Stephen Curry  Golden State Warriors      Vice-Champion
# 67  2017  Russell Westbrook  Oklahoma City Thunder  Not reached Final
# 68  2018       James Harden        Houston Rockets  Not reached Final
#
# [69 rows x 4 columns]

# %%
#Extract CSV into DataFrames
players_df = pd.read_csv(players_file)
players_df.head()
#Grab Columns
players_col= ['player_id', 'name']
new_players_df= players_df[players_col].copy()
new_players_df.head()
# Out:
#    player_id                 name
# 0  abdelal01       Alaa Abdelnaby
# 1  abdulza01      Zaid Abdul-Aziz
# 2  abdulka01  Kareem Abdul-Jabbar
# 3  abdulma02   Mahmoud Abdul-Rauf
# 4  abdulta01    Tariq Abdul-Wahad

# %%
#Extract CSV into DataFrames
salaries_df=pd.read_csv(salaries_file)
salaries_df.head()
#Grab Columns
salaries_col=['player_id', 'season_end', 'salary']
new_salaries_df = salaries_df[salaries_col].copy()
new_salaries_df
# Out:
#        player_id  season_end   salary
# 0      abdelal01        1991   395000
# 1      abdelal01        1992   494000
# 2      abdelal01        1993   500000
# 3      abdelal01        1994   805000
# 4      abdelal01        1995   650000
# ...          ...         ...      ...
# 14159  zipsepa01        2017   750000
# 14160  zipsepa01        2018  1312611
# 14161  zizican01        2018  1645200
# 14162  zubaciv01        2017  1034956
# 14163  zubaciv01        2018  1312611
#
# [14164 rows x 3 columns]

# %%
#Find the average salary per player ID
salary_df = new_salaries_df.groupby('player_id')
salary_df.head()
avg_salary_mean = salary_df["salary"].mean()
avg_salary_mean
# Out:
# player_id
# abdelal01    5.688000e+05
# abdulka01    2.140000e+06
# abdulma02    2.205500e+06
# abdulta01    3.798280e+06
# abdursh01    8.715091e+06
#                  ...
# zidekge01    6.937333e+05
# zimmest01    9.500000e+05
# zipsepa01    1.031306e+06
# zizican01    1.645200e+06
# zubaciv01    1.173784e+06
# Name: salary, Length: 2409, dtype: float64

# %%
#Create DataFrame with average salary per player ID
avg_salary_df = pd.DataFrame({"avg_salary_per_player": avg_salary_mean})
avg_salary_df.style.format({'avg_salary_per_player': '${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_12f16254_0760_11ea_86b4_94659cde42c9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >avg_salary_per_player</th>    </tr>    <tr>        <th class="index_name level0" >player_id</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row0" class="row_heading level0 row0" >abdelal01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row0_col0" class="data row0 col0" >$568,800.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row1" class="row_heading level0 row1" >abdulka01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row1_col0" class="data row1 col0" >$2,140,000.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row2" class="row_heading level0 row2" >abdulma02</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row2_col0" class="data row2 col0" >$2,205,500.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row3" class="row_heading level0 row3" >abdulta01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row3_col0" class="data row3 col0" >$3,798,280.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row4" class="row_heading level0 row4" >abdursh01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row4_col0" class="data row4 col0" >$8,715,090.91</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row5" class="row_heading level0 row5" >abrinal01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row5_col0" class="data row5 col0" >$5,859,882.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row6" class="row_heading level0 row6" >ackeral01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row6_col0" class="data row6 col0" >$649,829.33</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row7" class="row_heading level0 row7" >acresma01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row7_col0" class="data row7 col0" >$321,800.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row8" class="row_heading level0 row8" >acyqu01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row8_col0" class="data row8 col0" >$1,146,500.86</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row9" class="row_heading level0 row9" >adamsal01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row9_col0" class="data row9 col0" >$591,666.67</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row10" class="row_heading level0 row10" >adamsha01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row10_col0" class="data row10 col0" >$354,940.50</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row11" class="row_heading level0 row11" >adamsjo01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row11_col0" class="data row11 col0" >$1,404,600.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row12" class="row_heading level0 row12" >adamsmi01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row12_col0" class="data row12 col0" >$826,500.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row13" class="row_heading level0 row13" >adamsst01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row13_col0" class="data row13 col0" >$6,433,461.40</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row14" class="row_heading level0 row14" >addisra01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row14_col0" class="data row14 col0" >$346,600.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row15" class="row_heading level0 row15" >adebaba01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row15_col0" class="data row15 col0" >$2,490,360.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row16" class="row_heading level0 row16" >adrieje01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row16_col0" class="data row16 col0" >$662,881.40</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row17" class="row_heading level0 row17" >afflaar01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row17_col0" class="data row17 col0" >$4,904,346.58</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row18" class="row_heading level0 row18" >agerma01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row18_col0" class="data row18 col0" >$751,656.25</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row19" class="row_heading level0 row19" >aguirma01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row19_col0" class="data row19 col0" >$908,515.56</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row20" class="row_heading level0 row20" >ahearbl01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row20_col0" class="data row20 col0" >$125,562.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row21" class="row_heading level0 row21" >aingeda01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row21_col0" class="data row21 col0" >$977,777.78</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row22" class="row_heading level0 row22" >ajincal01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row22_col0" class="data row22 col0" >$2,708,446.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row23" class="row_heading level0 row23" >akognjo01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row23_col0" class="data row23 col0" >$788,872.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row24" class="row_heading level0 row24" >alabiso01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row24_col0" class="data row24 col0" >$800,000.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9level0_row25" class="row_heading level0 row25" >alarima01</th>
#                         <td id="T_12f16254_0760_11ea_86b4_94659cde42c9row25_col0" class="data row25 col0" >$383,125.00</td>
#             </tr>
#             <tr>
#                         <th id="T_12f16254_0760_11ea_86b4_94659cde42c9

# %%
#Create database connection
connection_string = "postgres:postgres@localhost:5432/nba_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['mvp', 'players', 'salaries']

# %%
#Load DataFrames into database
new_mvp_df.to_sql(name='mvp', con=engine, if_exists='append', index=False)

# %%
#Load DataFrames into database
new_players_df.to_sql(name='players', con=engine, if_exists='append', index=False)

# %%
#Load DataFrames into database
avg_salary_df.to_sql(name='salaries', con=engine, if_exists='append', index=True)
